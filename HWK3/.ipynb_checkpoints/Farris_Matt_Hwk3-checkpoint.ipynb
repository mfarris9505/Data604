# %% [markdown]
# # Homework 3

# %% [markdown]
# ## Introduction

# %% [markdown]
# For homework 3, we were asked to run the simulations in Excel... I, however, do not use excel (except when forced), and I think you prof., have a similar aversion to it. I am hoping you are not forcing us to stick with the book. So, I decide to test myself a little bit, and throw out some Python code (I saw you mentioned Simpy in the discussion board, so I want to try and throw in a little of that into my work over the course along with Simio and Jaamsim, but I need to dust off my python coding as I have been out of practice for about 6 months while I focused on R.)

# %% [markdown]
# ## Problem 1

# %% [markdown]
# For Problem one, we are going to "adjust the problem" to fit the program element I'll be using. First, part C will be eliminated... I know it says to use an excel spreadsheet, but I do not think that is challenging enough, I personally moved past excel when I started this Data Analytics program. So, instead, we are going to change Part C into the underworks of the Gambling trade....

# %% [markdown]
# ### Part A:

# %% [raw]
# For this problem we are reproducing several basic simulations. We will be running "for" loops, again, as I feel this is the most intuitive way to run a programmic "simulation" as at each iteration a new random value is produced. As this is more of a "let's learn the process" program, I am creating a redundant program that creates each roll separately with a uniform random distriubtion.

# %%
import numpy as np
import pandas as pd

def dice_roll (number):
    """
    Fair roll of 2 dices: Inputs are the number of rolls, 
    and the output is the number on each dice and the total sum. 
    """
    dice_1 = []
    dice_2 = [] 
    sum_dice =[]
    for i in range(1,number+1):    
        x = np.random.randint(1,6)
        y = np.random.randint(1,6)
        z = x+y
        dice_1.append(x)
        dice_2.append(y)
        sum_dice.append(z)


    result = pd.DataFrame({"Dice 1":dice_1,"Dice 2":dice_2,"Roll":sum_dice})
    result.index += 1
    return result

# %% [raw]
# The above code mimics a fair dice roll and we will first produce a random sampling of 50 dice rolls first as comparision, along with a 500 fair dice roll:

# %%
result_50 = dice_roll(50)
result_500 = dice_roll(500)

# %% [markdown]
# A quick peek at the top ten rolls shows us the following:

# %%
result_50.head(10)
result_500.head(10)
# Out:
#     Dice 1  Dice 2  Roll
# 1        1       3     4
# 2        1       3     4
# 3        5       4     9
# 4        3       3     6
# 5        3       4     7
# 6        4       2     6
# 7        3       2     5
# 8        4       2     6
# 9        3       3     6
# 10       1       3     4

# %% [markdown]
# Plotting the sum of each roll as a histogram we can see the distribution across first the 50 rolls, and then the 500:

# %%
from bokeh.charts import *
from bokeh.layouts import row

p1 = Histogram(result_50, 
               values='Roll',
               title="Rolling 2 Dice 50 Times")
p2 = Histogram(result_500, 
               values='Roll',
               color='navy',
               title="Rolling 2 Dice 500 Times")

output_notebook()

show(row(p1,p2))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9f21477d-afb7-410d-a414-af3f16815d78">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="e53baf39-f740-4f67-8325-e3b0e6f28f35"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e53baf39-f740-4f67-8325-e3b0e6f28f35").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e53baf39-f740-4f67-8325-e3b0e6f28f35");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e53baf39-f740-4f67-8325-e3b0e6f28f35' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bf17bb45-1916-4984-a79b-67cb81f626c7":{"roots":{"references":[{"attributes":{"plot":{"id":"ff4da476-2594-4929-97e0-ced8d6a84efa","subtype":"Chart","type":"Plot"}},"id":"eb38aa56-dae1-4f2b-b30f-0c7059b49d2f","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7dd0d94-36a6-4528-9e3e-c3b0854d137b","type":"Rect"},{"attributes":{"axis_label":"Roll","formatter":{"id":"a01307b3-c274-4639-b9a8-b9524d602945","type":"BasicTickFormatter"},"plot":{"id":"ff4da476-2594-4929-97e0-ced8d6a84efa","subtype":"Chart","type":"Plot"},"ticker":{"id":"a1351d62-d45c-4ee3-b719-44f8555708a9","type":"BasicTicker"}},"id":"93eb26c2-dce5-453c-836b-dadd13adc171","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.5, 6.0]"],"color":["navy"],"fill_alpha":[0.8],"height":[0.0],"label":["(5.5, 6.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5],"x":["5.75"],"y":[0.0]}},"id":"a36fbbd6-a822-46c6-ac85-ea23f9881c42","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d7e62ec-ba4e-4bf8-98c2-08bea4fe0ca2","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0213af6b-59cb-4d63-9bd1-ce41f1fa4861","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"075c1054-537d-46e3-ae07-cc439d4d2323","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b9e78c0-2548-4a34-9209-92f888a6c954","type":"Rect"},{"attributes":{"callback":null,"end":17.6},"id":"dbe2a7c6-f093-433a-b886-ae33fb5a45a7","type":"Range1d"},{"attributes":{"axis_label":"Count( Roll )","formatter":{"id":"dc836681-6934-416d-9c42-2d8da5f9cb79","type":"BasicTickFormatter"},"plot":{"id":"2432f194-8d00-4602-a841-84509275214d","subtype":"Chart","type":"Plot"},"ticker":{"id":"c56daf30-e79b-495b-a3a5-b10d9099fe69","type":"BasicTicker"}},"id":"939e5ffb-ea22-4f99-aaa5-e71c5ff0ce71","type":"LinearAxis"},{"attributes":{},"id":"a7dd059d-3265-4247-9863-188f1449f032","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2432f194-8d00-4602-a841-84509275214d","subtype":"Chart","type":"Plot"}},"id":"2ac57219-3558-4322-91bf-42e97e1947de","type":"HelpTool"},{"attributes":{"location":"top_left","plot":{"id":"ff4da476-2594-4929-97e0-ced8d6a84efa","subtype":"Chart","type":"Plot"}},"id":"6e63ae6d-3175-4533-baa3-fbc1bce4bf5b","type":"Legend"},{"attributes":{"data_source":{"id":"a19e97e3-677e-4499-aeed-ad8f266d5d05","type":"ColumnDataSource"},"glyph":{"id":"7761a93b-c095-407f-881e-2c569d02701e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4d2fd3ce-67ea-4b17-b9f2-33c0e881fcef","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(8.0, 8.5]"],"color":["navy"],"fill_alpha":[0.8],"height":[53.0],"label":["(8.0, 8.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5],"x":["8.25"], ...

# %% [markdown]
# As you can see from the above, the distribution at 500 shows more of a uniformed distribution centering around 7 rolls. This makes sense as the most common roll given any 2 dice will be a total of 7.

# %% [markdown]
# ### Part B (and C)???

# %% [markdown]
# For Part B and C (because I don't like part C and will not be using Excel) we will be changing the roll from a standard uniform distribution, and adjusting the probablity of the roll.
#
# So, let's change up the problem a bit, let's assume that there are two intrepid cheaters, who love to play craps.  And for simplicity, let's say these intrepid cheaters have found a way to load a dice during a game of craps, to double the probability of one single number appear on any of the die (ie. make that number approximately appear 2 times for every 6 rolls as opposed to 1). Though these cheaters are good at making dice, they are TERRIBLE at probability theory. So they decided to do there best, and run simulations. Knowing their greatest profits come from betting all the hardways (I'll be honest, my craps is very limited, all I know is "all the hard-ways" I am sure there is a better way to bet, but this is hypothetical) Which number should they pick to get both dice to hit the hard way bet? Assume also, that an increase in 2,3 and 12, can also adversely effect their winnings(ie. crapping out).
#
# For this problem, we likewise will do what the book says for part B, and run simulations against the weighted dice. First we create the function:

# %%
def weighted_dice (number, prob):
    """
    Unfair roll of 2 dices: Inputs are the number of rolls, 
    and the output is the number on each dice and the total sum. 
    """
    dice_1 = []
    dice_2 = [] 
    sum_dice =[]
    for i in range(1,number+1):
        x = np.random.choice(range(1,7),p = prob)
        y = np.random.choice(range(1,7),p = prob)
        z = x+y
        dice_1.append(x)
        dice_2.append(y)
        sum_dice.append(z)


    result = pd.DataFrame({"Dice 1":dice_1,"Dice 2":dice_2,"Roll":sum_dice})
    result.index += 1
    return result

# %%
prob_5 = [float(2)/15,float(2)/15,float(2)/15,float(2)/15,float(2)/6,float(2)/15]

# %%
weighted = weighted_dice(50, prob_5)

# %%
weighted.head(10)
# Out:
#     Dice 1  Dice 2  Roll
# 1        1       6     7
# 2        6       4    10
# 3        1       1     2
# 4        5       5    10
# 5        4       1     5
# 6        6       5    11
# 7        6       6    12
# 8        3       4     7
# 9        5       3     8
# 10       3       2     5

# %% [markdown]
# The above shows the first 50 rolls of a weighted die for luck number 5. Plotting a histogram to see the distribution gives us the following

# %%
p1 = Histogram(weighted, 
               values='Roll',
               title="Weighted Fives")

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="099fe68b-9cd9-414a-839a-66dd8a7f8f2d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#099fe68b-9cd9-414a-839a-66dd8a7f8f2d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("099fe68b-9cd9-414a-839a-66dd8a7f8f2d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '099fe68b-9cd9-414a-839a-66dd8a7f8f2d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6be3e014-3725-4f7c-921d-ebbb6bb2323e":{"roots":{"references":[{"attributes":{"plot":{"id":"17a3a67f-ab0f-4feb-8ee2-9447bd672682","subtype":"Chart","type":"Plot"}},"id":"7d5483ee-713f-4d73-8d68-083c6c9eb404","type":"SaveTool"},{"attributes":{"callback":null,"end":12.35,"start":1.65},"id":"aadf42e5-daea-4c10-b091-60a899ec5a5d","type":"Range1d"},{"attributes":{"data_source":{"id":"451cf3f8-b91a-45bb-90af-2c2a7a3d3d14","type":"ColumnDataSource"},"glyph":{"id":"86088d56-b11c-4f71-83ce-72c1a4121f38","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"35133298-e932-4fd4-9508-8c7bff7103ae","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"17a3a67f-ab0f-4feb-8ee2-9447bd672682","subtype":"Chart","type":"Plot"}},"id":"f20d1830-4248-4d9d-8433-743ae60b7465","type":"HelpTool"},{"attributes":{"overlay":{"id":"d3b163d0-686d-40ac-b9ec-91278ee4299a","type":"BoxAnnotation"},"plot":{"id":"17a3a67f-ab0f-4feb-8ee2-9447bd672682","subtype":"Chart","type":"Plot"}},"id":"70a57d78-ec80-4378-8db4-685fa7ee98de","type":"BoxZoomTool"},{"attributes":{"axis_label":"Roll","formatter":{"id":"c4dbb3b8-a1d3-40f1-bcb0-fb5fce2870f1","type":"BasicTickFormatter"},"plot":{"id":"17a3a67f-ab0f-4feb-8ee2-9447bd672682","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e1eed82-6c1a-4c52-ba0c-b80066ccff9a","type":"BasicTicker"}},"id":"e9ef64e9-0ab2-4622-ade6-d6fe100f43ac","type":"LinearAxis"},{"attributes":{},"id":"beec79f6-67d8-46de-bf47-f30a22019b34","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"040ec12b-a293-4d17-aba9-b69ad7ebe63f","type":"ColumnDataSource"},"glyph":{"id":"2321b815-237c-4b6d-b9a5-93d023f84197","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bc20fa27-0ab0-41e9-b844-f51d954ed4fb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86088d56-b11c-4f71-83ce-72c1a4121f38","type":"Rect"},{"attributes":{},"id":"60baf12f-3779-4dea-9a09-bf505fb254f8","type":"ToolEvents"},{"attributes":{},"id":"1e1eed82-6c1a-4c52-ba0c-b80066ccff9a","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"aa01ad6d-4761-478a-86f5-48d7fe6add2e","type":"PanTool"},{"id":"ab17bcac-b751-4e20-b4b8-ab64c2f9039e","type":"WheelZoomTool"},{"id":"70a57d78-ec80-4378-8db4-685fa7ee98de","type":"BoxZoomTool"},{"id":"7d5483ee-713f-4d73-8d68-083c6c9eb404","type":"SaveTool"},{"id":"0557cff0-5e11-43ea-bb1b-0883f3bb33a0","type":"ResetTool"},{"id":"f20d1830-4248-4d9d-8433-743ae60b7465","type":"HelpTool"}]},"id":"df04d66d-2676-48fc-a127-5265afea5f40","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["[2.0, 4.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["[2.0, 4.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0],"x":["3.0"],"y":[1.0]}},"id":"bda989f6-e2dd-4740-9adf-057e36a2e9ef","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c3dabd76-1ac7-49b4-b3e4-ba4ee034d1cb","type":"Rect"},{"attributes":{"axis_label":"Count( Roll )","formatter":{"id":"beec79f6-67d8-46de-bf47-f30a22019b34","type":"BasicTickFormatter"},"plot":{"id":"17a3a67f-ab0f-4feb-8ee2-9447bd672682","subtype":"Chart","type":"Plot"},"ticker":{"id":"c59c92cb-0998-408c-9909-13cee82be108","type":"BasicTicker"}},"id":"46f1710d-0509-43c2-ab0f-aefdf5fb53e9","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height"," ...

# %% [markdown]
# Now we know that this shows only 50 rolls, and we can see some changes, however, with this few rolls we cannot tell if there is much of a difference, so we will proceed with a larger sample of 10,000 as suggested by the book for part c.

# %%
weighted = weighted_dice(10000, prob_5)
p1 = Histogram(weighted, 
               values='Roll',
               title="Weighted Fives")

output_notebook()

show(p1)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ecae247f-28ae-487a-b1a4-06178b3cb5c0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="1c422d2e-0cb0-44ff-8407-6251b15857f4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1c422d2e-0cb0-44ff-8407-6251b15857f4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c422d2e-0cb0-44ff-8407-6251b15857f4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c422d2e-0cb0-44ff-8407-6251b15857f4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9b8fc629-6e1c-4aeb-a6d2-b65bffa8168a":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(7.6, 7.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(7.6, 7.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.27777777777777857],"x":["7.7"],"y":[0.0]}},"id":"72618b3f-e715-4e79-ae0d-16b1d5f2df4d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b473527f-cfec-4476-b5d3-3c5599155371","type":"Rect"},{"attributes":{"plot":null,"text":"Weighted Fives"},"id":"661cc105-962c-4c04-85ae-784e133af725","type":"Title"},{"attributes":{"data_source":{"id":"f7d9b843-0fb8-40b5-a367-86c079bf80a4","type":"ColumnDataSource"},"glyph":{"id":"846e34eb-e859-4e2b-94fe-6a51f44144a1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fd66f33f-aacc-43dd-a57b-b518d75ed02a","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":12.338888888888887,"start":1.661111111111111},"id":"e7b1e858-1cda-48ed-8ffb-c9a44a019e9d","type":"Range1d"},{"attributes":{"data_source":{"id":"10344bf4-c21b-4156-8562-7448604ce872","type":"ColumnDataSource"},"glyph":{"id":"1d756b51-31eb-4fac-b109-b3df4493f9d0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9f6c1549-7d70-4d2d-be2d-1f96cf4737c7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(11.2, 11.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(11.2, 11.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.2777777777777768],"x":["11.3"],"y":[0.0]}},"id":"f7590434-61a4-4d73-8165-a66774e4fc0a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"153c5119-c48c-49b7-9234-db019d8ac7c5","subtype":"Chart","type":"Plot"}},"id":"cb3fbcc2-3994-431b-a516-0bbfec6ba62c","type":"HelpTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"24a34cec-8d9c-4c59-a061-840fc3dd591f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fad15d32-cd76-420b-9588-8603229c0c8e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61433bc7-27dc-4345-a65f-30c5194443e5","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(8.9, 9.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1207.0],"label":["(8.9, 9.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.2777777777777768],"x":["9.05"],"y":[603.5]}},"id":"d14a2be5-9ed2-4957-b586-a2509ea5edfd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6bafa72e-2c02-4e9d-b3e4-c933303f2582","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"l ...

# %% [markdown]
# Similarly, we can do this with all the dice rolls and compare them to a normal dice roll:

# %%
prob_4 = [float(2)/15,float(2)/15,float(2)/15,float(2)/6,float(2)/15,float(2)/15]
prob_3 = [float(2)/15,float(2)/15,float(2)/6,float(2)/15,float(2)/15,float(2)/15]
prob_2 = [float(2)/15,float(2)/6,float(2)/15,float(2)/15,float(2)/15,float(2)/15]

weighted_4 = weighted_dice(10000, prob_4)
weighted_3 = weighted_dice(10000, prob_3)
weighted_2 = weighted_dice(10000, prob_2)
fair = dice_roll(10000)

# %%
p1 = Histogram(weighted_4, 
               values='Roll',
               title="Weighted Fours")
p2 = Histogram(weighted_3, 
               values='Roll',
               color='purple',
               title="Weighted Threes")
p3 = Histogram(weighted_2, 
               values='Roll',
               color='green',
               title="Weighted Twos")
p4 = Histogram(fair, 
               values='Roll',
               color='navy',
               title="Fair Dice Roll 10,000 Times")

output_notebook()

show(row(p1,p2))
show(row(p3,p4))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7f26631a-6f75-4d36-a30b-b1b6a8a9f6f6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="80eef26b-a5fb-4e69-bf21-ad4dd36fe7d9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#80eef26b-a5fb-4e69-bf21-ad4dd36fe7d9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80eef26b-a5fb-4e69-bf21-ad4dd36fe7d9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80eef26b-a5fb-4e69-bf21-ad4dd36fe7d9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"aa844595-a315-442c-b29f-7a2bc6e4919d":{"roots":{"references":[{"attributes":{"plot":null,"text":"Weighted Threes"},"id":"ed845a42-8314-4ea3-91fc-f4c7871870a5","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c88075e6-68e8-4504-bfac-61fdca56485d","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(3.7, 3.9]"],"color":["purple"],"fill_alpha":[0.8],"height":[0.0],"label":["(3.7, 3.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.2777777777777777],"x":["3.8"],"y":[0.0]}},"id":"527ceba1-898b-4df2-bb39-6b8f5ef440da","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"86895e26-b68e-4716-bacc-6263766ad220","type":"BoxAnnotation"},"plot":{"id":"d5d4e97b-f902-4ddf-bcb9-5a0e97505fe1","subtype":"Chart","type":"Plot"}},"id":"6854b147-3461-46c0-a46d-13252c8d78f1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d5d4e97b-f902-4ddf-bcb9-5a0e97505fe1","subtype":"Chart","type":"Plot"}},"id":"177a773a-1d2e-4d9c-aac9-335f1c6a2ed3","type":"ResetTool"},{"attributes":{"data_source":{"id":"765f82df-3daf-44c6-9c13-ab60c9e5af0b","type":"ColumnDataSource"},"glyph":{"id":"2774188f-7ea0-455e-8bba-234a3cd71293","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"73aa3dc7-c399-4023-8124-c631c5aa89b4","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"46d33add-111d-49ef-80bf-202f4744336c","type":"Rect"},{"attributes":{"data_source":{"id":"0d667365-3cc2-49f5-b744-2d8d993abd29","type":"ColumnDataSource"},"glyph":{"id":"e7b6b1b3-13a8-4ed0-bfe3-60ddba9537c8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"eaa9bdd5-49ce-46d9-b6ed-77f5f18f4686","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61ccd092-3bc4-40e4-9efa-b4f1714dfb52","type":"Rect"},{"attributes":{"children":[{"id":"d5d4e97b-f902-4ddf-bcb9-5a0e97505fe1","subtype":"Chart","type":"Plot"},{"id":"ed1066bd-1c37-4cb5-a1ce-80600645181a","subtype":"Chart","type":"Plot"}]},"id":"9732b2f4-e87b-46d7-b8f9-0aa676a89cd3","type":"Row"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(10.6, 10.9]"],"color":["purple"],"fill_alpha":[0.8],"height":[0.0],"label":["(10.6, 10.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.27777777777777857],"x":["10.75"],"y":[0.0]}},"id":"e9027ce8-6e9b-4f74-9283-d6e574ff0ef1","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c759e885-a625-4732-9620-312143b22263","type":"ColumnDataSource"},"glyph":{"id":"a6eca314-946b-4b7c-8e25-128d776df04d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fb0e8029-1fba-4d02-81be-c954e297b113","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a755aa55-c878-4ad4-bc50-901a3065d096","type":"ColumnDataSource"},"glyph":{"id":"49cce705-fe3c-4c23-b1a5-98ead36ceca2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8237276f-4733-4777-8123-6fc75425e581","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5b9bb500-a76e-41d4-900b-708625d301c3","type":"ColumnDataSource"},"glyph":{"id":"3ce6209e-f428-4f25-b9c9-429a56dda969","type":"Rect"},"hover_glyph":null,"nonselection_ ...
#     <div class="bk-root">
#         <div class="plotdiv" id="841b2349-2095-424e-ab02-e89f892870d4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#841b2349-2095-424e-ab02-e89f892870d4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("841b2349-2095-424e-ab02-e89f892870d4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '841b2349-2095-424e-ab02-e89f892870d4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f44b6c76-1a65-454f-be62-7e6ff55cb0bc":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ace4f49-1d9b-492a-84ff-26b964fe8c36","type":"Rect"},{"attributes":{"data_source":{"id":"ecb97dda-22c3-4597-b248-dbd268aca4d7","type":"ColumnDataSource"},"glyph":{"id":"99745581-2bc4-48ec-9d82-83ed867fad92","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dabed7d8-3fa1-4ca1-813e-0cedac907b98","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"18fca4ac-d375-4cfa-ad93-90106dfe0b2b","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(2.9, 3.1]"],"color":["navy"],"fill_alpha":[0.8],"height":[818.0],"label":["(2.9, 3.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18181818181818166],"x":["3.0"],"y":[409.0]}},"id":"e48901d3-9c3a-4e8d-b9f0-ba13349728a0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(6.4, 6.8]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(6.4, 6.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.37037037037037024],"x":["6.6"],"y":[0.0]}},"id":"550b2935-218b-4865-b138-604d2a688d88","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(8.3, 8.7]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(8.3, 8.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.37037037037037024],"x":["8.5"],"y":[0.0]}},"id":"91bae746-389e-453a-b224-541144a66ec8","type":"ColumnDataSource"},{"attributes":{},"id":"f4966317-74ef-49d2-b936-90cdf0c5ec13","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(6.4, 6.5]"],"color":["navy"],"fill_alpha":[0.8],"height":[0.0],"label":["(6.4, 6.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18181818181818254],"x":["6.45"],"y":[0.0]}},"id":"601fd905-16cd-4613-bff1-29ee89e6744d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6bb6ed51-c28f-43b6-a1c3-fc158a5fef7a","type":"Rect"},{"attributes":{"data_source":{"id":"f6cd904d-9e17-49b5-bb02-03f141400f78","type":"ColumnDataSource"},"glyph":{"id":"21b59155-ca4c-4c1b-a235-2499eef0aa29","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a96e3036-31bd-4237-a806-d6a91ac8636b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"22363e6a-b8e3-4d4f-944a-4f201bf3898b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dca755ef-4ad7-4196-a7cf-97604b74ec8c","type":"Rect"},{"attributes":{"data_source":{"id":"6771f158-6bb8-4719-b2e5-819e61fef270","type":"ColumnData ...

# %% [markdown]
# From the above graphs, we can see that weighting one number of the dice irregardless of the which "hardway", will produce the desired effect and as you can see in all the graphs there was a substantial increase in the 4, 6, 8 and 10 rolls in their respective dices. However, when weighting the dice to roll a 2, we see a significant increase in the number of threes thrown. This would be very problematic for our gamblers, as it would increase the likelihood of crapping out. So, after all this, our astute gamblers should choose one of the other 3 numbers to produce a better change of increasing their profits.

# %% [markdown]
# ## Problem 5

# %% [markdown]
# For this problem, we are going to replicate the data from the text, using the formulas in python. In the scipy package, there is a function that will find the density given any

# %%
from scipy.stats import norm

# %%
def norm_dist (number):
    """
    Fair roll of 2 dices: Inputs are the number of rolls, 
    and the output is the number on each dice and the total sum. 
    """
    random = []
    density =[]
    for i in range(1,number+1):    
        x = np.random.uniform(4.5,6.7)
        y = (6.7-4.5)*norm(5.80,2.30).pdf(x)
        random.append(x)
        density.append(y)


    result = pd.DataFrame({"Rand":random,"Density":density})
    result.index += 1
    return result

# %%
norm_data = norm_dist(50)
norm_data.head(10)
# Out:
#      Density      Rand
# 1   0.349775  4.840180
# 2   0.379119  5.537469
# 3   0.332723  4.595821
# 4   0.348109  4.814218
# 5   0.368749  6.401951
# 6   0.333599  4.607436
# 7   0.347583  4.806143
# 8   0.355747  4.938519
# 9   0.378439  6.096521
# 10  0.373119  6.287539

# %%
norm_data["Density"].mean()
# Out:
# 0.36311816932965224

# %%
norm_data["Density"].std()
# Out:
# 0.015101290128272254

# %%
def test_for_norm(trial,exact,conf):
    """ The inputs for this function are the number of trials
    the exact value of the integral and the confidence interval
    expressed as a number of standard deviations from the mean.
    """
    fails = 0
    for i in range(1,trial+1):
        x = norm_dist(50)
        mean_x = x["Density"].mean()
        std_x = x["Density"].std()
        r1 = exact - (conf * std_x)
        r2 = exact + (conf * std_x)
        if mean_x <= r1:
            fails = fails + 1
        elif mean_x >= r2:
            fails = fails + 1 
    return fails

# %%
test_for_norm(100,0.3663,.5)
# Out:
# 1

# %% [markdown]
# Honestly, even with the variation in the monte-carlo experiment, so far this has yet to produce any simulations where the mean falls outside the confidence interval. The test only comes back a failure when I plug in a confidence range of .5 of the standard deviation (which is less than the 66% of a single standard deviation). I am not sure if my code is correct however, and it is possible that I am making an error.

# %% [markdown]
# ## Problem 17

# %% [markdown]
# Though I had completed this project in R for the discussion, I decided to reproduce the functions here, and create a simulation on the previously built model, as I saw some in the discussion, and thought it would be benefical to reproduce these designs.

# %% [markdown]
# In this problem, we are analysing a simple day to day business of selling oats, peas, beans, and barley. For this project, I chose to use a For Loop in R. For me, this is an obvious choice, albeit a somewhat of a extravagent step. For the most part For loops are a thing of the past, and tend to gummy up the work. However, I feel that for this class especially, for-loops are an intuitive method for wrapping one's head around a simulation, as opposed to using the apply function or other ways to create just a mass block of "simulated data."

# %%
#Initiating Variables
prod = ["oats","peas","beans","barley"]
cost = [1.05,3.17,1.99,0.95]
price = [1.29,3.76,2.23,1.65]
lbs_o = range(0,11)
lbs_p = range(0,9)
lbs_bn = range(0,15)
lbs_ba = range(0,12)

# %%
#Creating a Function

def sum_sale(days):
    """
    The input on this function is the number of days in the season,
    which is a representation of the number of "runs" The output is a
    dataframe
    """
    o = []
    p = []
    bn = []
    ba = []
    for i in range(1,days+1):
        w = np.random.choice(lbs_o)
        x = np.random.choice(lbs_p)
        y = np.random.choice(lbs_bn)
        z = np.random.choice(lbs_ba)
        o.append(w)
        p.append(y)
        bn.append(y)
        ba.append(z)
        
    result = pd.DataFrame({"Oats":o,"Peas":p,"Beans":bn,"Barley":ba})
    result.index += 1
    tot_cost = np.multiply(result, cost).sum(axis=1)
    tot_price = np.multiply(result, price).sum(axis=1)
    tot_rev = tot_price - tot_cost
    result['Cost'] = tot_cost
    result['Price'] = tot_price
    result['Revenue'] = tot_rev
    
    return result

# %%
results = sum_sale(90)

# %%
results.head(10)
# Out:
#     Barley  Beans  Oats  Peas   Cost  Price  Revenue
# 1        0      0     0     0   0.00   0.00     0.00
# 2        0      0     3     0   5.97   6.69     0.72
# 3        1     11     5    11  56.32  71.95    15.63
# 4        6      2     3     2  20.51  25.25     4.74
# 5        7     11     1    11  54.66  70.77    16.11
# 6        5      2     5     2  23.44  28.42     4.98
# 7       10     12     9    12  77.85  97.89    20.04
# 8        5      2     6     2  25.43  30.65     5.22
# 9        9      3     1     3  23.80  30.07     6.27
# 10       9      4     5     4  35.88  44.40     8.52

# %% [markdown]
# As you can see from the above, we have created a function that produces the required day to day sales, which is exactly what we need to show how much our seller makes per day.
#
# However, since we want to run a simulation of a 1000 summers, it is necessary to cut out some functions and produce a code that shows just the summer total values to compare the range of values over the course of multiple summers. To do this we are going to cut down the code tou just total values

# %%
def sum_sale_int(itr,days):
    """
    The input on this function is the number of days in the season,
    which is a representation of the number of "runs" The output is a
    dataframe
    """
    cost_data = []
    price_data = []
    rev_data = []
    for i in range(0,itr+1):
        o = []
        p = []
        bn = []
        ba = []
        for i in range(1,days+1):
            w = np.random.choice(lbs_o)
            x = np.random.choice(lbs_p)
            y = np.random.choice(lbs_bn)
            z = np.random.choice(lbs_ba)
            o.append(w)
            p.append(y)
            bn.append(y)
            ba.append(z)
        
        result = pd.DataFrame({"Oats":o,"Peas":p,"Beans":bn,"Barley":ba})
        result.index += 1
        tot_cost = np.multiply(result, cost).sum(axis=1)
        tot_price = np.multiply(result, price).sum(axis=1)
        tot_rev = tot_price - tot_cost
        cost_data.append(sum(tot_cost))
        price_data.append(sum(tot_price))
        rev_data.append(sum(tot_rev))
        
       
    data = pd.DataFrame({"Cost":cost_data,"Price":price_data,"Revenue":rev_data})
    result.index += 1    
    return data

# %%
itr = sum_sale_int(100,90)

# %%
itr.head(10)
# Out:
#       Cost    Price  Revenue
# 0  3867.77  4862.48   994.71
# 1  4003.95  5035.59  1031.64
# 2  3993.71  5024.12  1030.41
# 3  3880.52  4899.32  1018.80
# 4  3856.09  4832.74   976.65
# 5  3643.57  4564.90   921.33
# 6  3778.55  4757.63   979.08
# 7  4212.94  5317.15  1104.21
# 8  4014.94  5063.77  1048.83
# 9  4214.79  5309.25  1094.46

# %%
itr.boxplot()
# Out:
# C:\Users\Matthew\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0xcd18550>,
#   <matplotlib.lines.Line2D at 0xcd48860>,
#   <matplotlib.lines.Line2D at 0xcd6bef0>],
#  'caps': [<matplotlib.lines.Line2D at 0xcd3b2b0>,
#   <matplotlib.lines.Line2D at 0xcd3b828>,
#   <matplotlib.lines.Line2D at 0xcd54940>,
#   <matplotlib.lines.Line2D at 0xcd54eb8>,
#   <matplotlib.lines.Line2D at 0xcd79fd0>,
#   <matplotlib.lines.Line2D at 0xcd85588>],
#  'fliers': [<matplotlib.lines.Line2D at 0xcd48358>,
#   <matplotlib.lines.Line2D at 0xcd6b9e8>,
#   <matplotlib.lines.Line2D at 0xcd950b8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xcd3bda0>,
#   <matplotlib.lines.Line2D at 0xcd6b470>,
#   <matplotlib.lines.Line2D at 0xcd85b00>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xcd18710>,
#   <matplotlib.lines.Line2D at 0xcd18cf8>,
#   <matplotlib.lines.Line2D at 0xcd48e10>,
#   <matplotlib.lines.Line2D at 0xcd543c8>,
#   <matplotlib.lines.Line2D at 0xcd794e0>,
#   <matplotlib.lines.Line2D at 0xcd79a58>]}

# %% [markdown]
# I will fix this boxplot... having trouble with bokeh and matlib.... to be continued.
